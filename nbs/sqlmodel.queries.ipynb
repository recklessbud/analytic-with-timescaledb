# %%
import sys
from pathlib import Path

# %%
src_path = Path("../src").resolve()
sys.path.append(str(src_path))

# %%
from api.db.session import engine
from api.events.models import EventSchema
from sqlmodel import Session, select

# %%
with Session(engine) as session:
    query = select(EventSchema).order_by(EventSchema.id.desc())
    results = session.exec(query).all()
    print(results)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 with Session(engine) as session:
#       2     query = select(EventSchema).order_by(EventSchema.id.desc())
# ----> 3     results = session.exec(query).all()
#       4     print(results)
#
# File c:\Users\reggi\Documents\fast-api-proj\.venv\Lib\site-packages\sqlmodel\orm\session.py:66, in Session.exec(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event)
#      52 def exec(
#      53     self,
#      54     statement: Union[
#    (...)     64     _add_event: Optional[Any] = None,
#      65 ) -> Union[TupleResult[_TSelectParam], ScalarResult[_TSelectParam]]:
# ---> 66     results = super().execute(
#      67         statement,
#      68         params=params,
#      69         execution_options=execution_options,
#      70         bind_arguments=bind_arguments,
#      71         _parent_execute_state=_parent_execute_state,
#      72         _add_event=_add_event,
#      73     )
#      74     if isinstance(statement, SelectOfScalar):
#      75         return results.scalars()
#
# File c:\Users\reggi\Documents\fast-api-proj\.venv\Lib\site-packages\sqlalchemy\orm\session.py:2365, in Session.execute(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event)
#    2305 def execute(
#    2306     self,
#    2307     statement: Executable,
#    (...)   2313     _add_event: Optional[Any] = None,
#    2314 ) -> Result[Any]:
#    2315     r"""Execute a SQL expression construct.
#    2316
#    2317     Returns a :class:`_engine.Result` object representing
#    (...)   2363
#    2364     """
# -> 2365     return self._execute_internal(
#    2366         statement,
#    2367         params,
#    2368         execution_options=execution_options,
#    2369         bind_arguments=bind_arguments,
#    2370         _parent_execute_state=_parent_execute_state,
#    2371         _add_event=_add_event,
#    2372     )
#
# File c:\Users\reggi\Documents\fast-api-proj\.venv\Lib\site-packages\sqlalchemy\orm\session.py:2241, in Session._execute_internal(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event, _scalar_result)
#    2227     (
#    2228         statement,
#    2229         execution_options,
#    (...)   2236         False,
#    2237     )
#    2239 bind = self.get_bind(**bind_arguments)
# -> 2241 conn = self._connection_for_bind(bind)
#    2243 if _scalar_result and not compile_state_cls:
#    2244     if TYPE_CHECKING:
#
# File c:\Users\reggi\Documents\fast-api-proj\.venv\Lib\site-packages\sqlalchemy\orm\session.py:2110, in Session._connection_for_bind(self, engine, execution_options, **kw)
#    2108 if trans is None:
#    2109     trans = self._autobegin_t()
# -> 2110 return trans._connection_for_bind(engine, execution_options)
#
# File <string>:2, in _connection_for_bind(self, bind, execution_options)
#
# File c:\Users\reggi\Documents\fast-api-proj\.venv\Lib\site-packages\sqlalchemy\orm\state_changes.py:137, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     135 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     136 try:
# --> 137     ret_value = fn(self, *arg, **kw)
#     138 except:
#     139     raise
#
# File c:\Users\reggi\Documents\fast-api-proj\.venv\Lib\site-packages\sqlalchemy\orm\session.py:1189, in SessionTransaction._connection_for_bind(self, bind, execution_options)
#    1184             raise sa_exc.InvalidRequestError(
#    1185                 "Session already has a Connection associated "
#    1186                 "for the given Connection's Engine"
#    1187             )
#    1188     else:
# -> 1189         conn = bind.connect()
#    1190         local_connect = True
#    1192 try:
#
# File c:\Users\reggi\Documents\fast-api-proj\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3271, in Engine.connect(self)
#    3248 def connect(self) -> Connection:
#    3249     """Return a new :class:`_engine.Connection` object.
#    3250
#    3251     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)   3268
#    3269     """
# -> 3271     return self._connection_cls(self)
#
# File c:\Users\reggi\Documents\fast-api-proj\.venv\Lib\site-packages\sqlalchemy\engine\base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     141 if connection is None:
#     142     try:
# --> 143         self._dbapi_connection = engine.raw_connection()
#     144     except dialect.loaded_dbapi.Error as err:
#     145         Connection._handle_dbapi_exception_noconnection(
#     146             err, dialect, engine
#     147         )
#
# File c:\Users\reggi\Documents\fast-api-proj\.venv\Lib\site-packages\sqlalchemy\engine\base.py:3295, in Engine.raw_connection(self)
#    3273 def raw_connection(self) -> PoolProxiedConnection:
#    3274     """Return a "raw" DBAPI connection from the connection pool.
#    3275
#    3276     The returned object is a proxied version of the DBAPI
#    (...)   3293
#    3294     """
# -> 3295     return self.pool.connect()
#
# File c:\Users\reggi\Documents\fast-api-proj\.venv\Lib\site-packages\sqlalchemy\pool\base.py:447, in Pool.connect(self)
#     439 def connect(self) -> PoolProxiedConnection:
#     440     """Return a DBAPI connection from the pool.
#     441
#     442     The connection is instrumented such that when its
#    (...)    445
#     446     """
# --> 447     return _ConnectionFairy._checkout(self)
#
# File c:\Users\reggi\Documents\fast-api-proj\.venv\Lib\site-packages\sqlalchemy\pool\base.py:1264, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1256 @classmethod
#    1257 def _checkout(
#    1258     cls,
#    (...)   1261     fairy: Optional[_ConnectionFairy] = None,
#    1262 ) -> _ConnectionFairy:
#    1263     if not fairy:
# -> 1264         fairy = _ConnectionRecord.checkout(pool)
#    1266         if threadconns is not None:
#    1267             threadconns.current = weakref.ref(fairy)
#
# File c:\Users\reggi\Documents\fast-api-proj\.venv\Lib\site-packages\sqlalchemy\pool\base.py:711, in _ConnectionRecord.checkout(cls, pool)
#     709     rec = cast(_ConnectionRecord, pool._do_get())
#     710 else:
# --> 711     rec = pool._do_get()
#     713 try:
#     714     dbapi_connection = rec.get_connection()
#
# File c:\Users\reggi\Documents\fast-api-proj\.venv\Lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     175     return self._create_connection()
#     176 except:
# --> 177     with util.safe_reraise():
#     178         self._dec_overflow()
#     179     raise
#
# File c:\Users\reggi\Documents\fast-api-proj\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     222     assert exc_value is not None
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#     226     self._exc_info = None  # remove potential circular references
#
# File c:\Users\reggi\Documents\fast-api-proj\.venv\Lib\site-packages\sqlalchemy\pool\impl.py:175, in QueuePool._do_get(self)
#     173 if self._inc_overflow():
#     174     try:
# --> 175         return self._create_connection()
#     176     except:
#     177         with util.safe_reraise():
#
# File c:\Users\reggi\Documents\fast-api-proj\.venv\Lib\site-packages\sqlalchemy\pool\base.py:388, in Pool._create_connection(self)
#     385 def _create_connection(self) -> ConnectionPoolEntry:
#     386     """Called by subclasses to create a new ConnectionRecord."""
# --> 388     return _ConnectionRecord(self)
#
# File c:\Users\reggi\Documents\fast-api-proj\.venv\Lib\site-packages\sqlalchemy\pool\base.py:673, in _ConnectionRecord.__init__(self, pool, connect)
#     671 self.__pool = pool
#     672 if connect:
# --> 673     self.__connect()
#     674 self.finalize_callback = deque()
#
# File c:\Users\reggi\Documents\fast-api-proj\.venv\Lib\site-packages\sqlalchemy\pool\base.py:899, in _ConnectionRecord.__connect(self)
#     897     self.fresh = True
#     898 except BaseException as e:
# --> 899     with util.safe_reraise():
#     900         pool.logger.debug("Error on connect(): %s", e)
#     901 else:
#     902     # in SQLAlchemy 1.4 the first_connect event is not used by
#     903     # the engine, so this will usually not be set
#
# File c:\Users\reggi\Documents\fast-api-proj\.venv\Lib\site-packages\sqlalchemy\util\langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     222     assert exc_value is not None
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#     226     self._exc_info = None  # remove potential circular references
#
# File c:\Users\reggi\Documents\fast-api-proj\.venv\Lib\site-packages\sqlalchemy\pool\base.py:895, in _ConnectionRecord.__connect(self)
#     893 try:
#     894     self.starttime = time.time()
# --> 895     self.dbapi_connection = connection = pool._invoke_creator(self)
#     896     pool.logger.debug("Created new connection %r", connection)
#     897     self.fresh = True
#
# File c:\Users\reggi\Documents\fast-api-proj\.venv\Lib\site-packages\sqlalchemy\engine\create.py:646, in create_engine.<locals>.connect(connection_record)
#     643         if connection is not None:
#     644             return connection
# --> 646 return dialect.connect(*cargs, **cparams)
#
# File c:\Users\reggi\Documents\fast-api-proj\.venv\Lib\site-packages\sqlalchemy\engine\default.py:626, in DefaultDialect.connect(self, *cargs, **cparams)
#     624 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     625     # inherits the docstring from interfaces.Dialect.connect
# --> 626     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File c:\Users\reggi\Documents\fast-api-proj\.venv\Lib\site-packages\psycopg\connection.py:110, in Connection.connect(cls, conninfo, autocommit, prepare_threshold, context, row_factory, cursor_factory, **kwargs)
#     108     conn_errors.append((ex, descr))
#     109 except e._NO_TRACEBACK as ex:
# --> 110     raise ex.with_traceback(None)
#     111 else:
#     112     logger.debug("connection succeeded: %s", descr)
#
# KeyboardInterrupt:
